# %% [markdown]
# ## Evaluate transfer learning on Turnedtable Watertank (Dataset 2)  using an SVM Classifier: Self-supervised approach

# %%
import tensorflow as tf
import h5py
import numpy as np
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
import sys
import os
sys.path.append('../../../')
sys.path.append('../../')

# %% [markdown]
# ### Configure Tensorflow for GPU device

# %%
tf.config.experimental_run_functions_eagerly(True)
print("[INFO] Tensorflow Version:", tf.__version__)

if tf.config.list_physical_devices("GPU") and tf.test.is_built_with_cuda():
    print("[INFO] Tensorflow built with CUDA")
    print("[INFO] Number GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
    print("[INFO] List of GPU devices:", tf.config.list_physical_devices("GPU"))
    physical_devices = tf.config.list_physical_devices("GPU")
    # tf.config.experimental.set_memory_growth(physical_devices[0], True)
    for gpu in physical_devices:
        tf.config.experimental.set_memory_growth(gpu, True)

else:
    print("[ERROR] GPU not detected, make sure tensorflow-gpu is installed and that GPU is recognized")
    exit()
# Out:
# [INFO] Tensorflow Version: 2.2.0
# [INFO] Tensorflow built with CUDA
# [INFO] Number GPUs Available:  1
# [INFO] List of GPU devices: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ### Define utilities

# %%
# utilities
def flatten(x):
    return x.reshape((x.shape[0], -1))

def classSampling(X, y, samplesPerClass, numberOfClasses):
    X_ret = np.zeros((samplesPerClass * numberOfClasses, X.shape[1]), dtype = np.float32)
    y_ret = np.zeros((samplesPerClass * numberOfClasses), dtype = np.uint8)
    count = 0

    for classIdx in range(numberOfClasses):
        indices = np.where(y == classIdx)[0]

        #if len(indices) < samplesPerClass:
        #    raise IndexError("Not enough samples for class {} to produce {} samples per class. Only {} class samples available".format(classIdx, samplesPerClass, len(indices)))

        doResample = len(indices) < samplesPerClass

        chosenIndices = np.random.choice(indices, samplesPerClass, replace = doResample)

        for ci in chosenIndices:
            X_ret[count] = X[ci]
            y_ret[count] = y[ci]

            count += 1

    return X_ret, y_ret

# %% [markdown]
# ### Define dataset and dataloader

# %%
class SonarTurnedTableSupervised(object):
    def __init__(self, file_path):
        self.file_path = file_path

    def _normalize_images(self, images):
        """
        Normalize sonar images by 1/255.
        """
        return [element/255.0 for element in images]

    def get_sonar_data(self):
        """
        Reads from HDF5 file containing sonar data (resized to fix dims).
        Returns list of np arrays containing image data.
        """

        print("[INFO] Retrieving Sonar Turned Table Supervised Data")

        with h5py.File(self.file_path, "r") as f:
            # list all groups
            print("hdf5 dataset keys: %s" % f.keys())

            # get images and labels
            x_train = f["x_train"][...].astype(np.float32)
            y_train = f["y_train"][...]

            x_test = f["x_test"][...].astype(np.float32)
            y_test = f["y_test"][...]

            _, x_val, _, y_val = train_test_split(x_test, y_test, train_size=0.5)

            print("[INFO] Data dimensions")
            print("Train", len(x_train))
            print("Val", len(x_val))
            print("Test", len(x_test))

            # matias normalization
            # multiply by 255 because hdf5 file comes as 1/255
            x_train *= 255.0
            x_val *= 255.0
            x_test *= 255.0

            x_train -= 84.51
            x_val -= 84.51
            x_test  -= 84.51

        return (x_train, y_train), (x_val, y_val), (x_test, y_test)
    
def load_sonar_turnedtable_supervised(file_path):
    """
    Loads test data from turnedtable dataset.
    """
    print()
    print("[INFO] Loading Tenorflow dataset")

    dataset_object = SonarTurnedTableSupervised(file_path)

    # Read data
    (x_train, y_train), (x_val, y_val), (x_test, y_test) = dataset_object.get_sonar_data()

    # Train data
    train_dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train))
    train_dataset = train_dataset.shuffle(buffer_size=len(x_train)).batch(len(x_train))
    train_dataset = train_dataset.prefetch(25)

    # Validation data
    # val_dataset = tf.data.Dataset.from_tensor_slices((x_val, labels_val))
    # val_dataset = val_dataset.shuffle(buffer_size=len(x_val)).batch(batch_size)
    # val_dataset = val_dataset.prefetch(25)

    # Test data
    test_dataset = tf.data.Dataset.from_tensor_slices((x_test, y_test))
    test_dataset = test_dataset.shuffle(buffer_size=len(x_test)).batch(len(x_test)) # feed full test set
    test_dataset = test_dataset.prefetch(25)

    print()
    print("[INFO] Tensorflow data dimensions")
    # print(train_dataset)
    # print(val_dataset)
    print(test_dataset)

    # return train_dataset, val_dataset, test_dataset
    return train_dataset, test_dataset

# %% [markdown]
# ###  Load Pretrained Model

# %%
from architectures.minixception import MiniXception

PRETRAINED_NUM_CLASSES = 4 # 11 supervised, 4 self-supervised
input_shape = [96, 96, 1]

model_name = "minixception"
pretraining_mode = "self_supervised_learning"
# layers = ["add_19", "add_18", "conv2d_35"]
layers = ["add_3", "add_2", "conv2d_6"]
model = MiniXception(input_shape, PRETRAINED_NUM_CLASSES)

model.summary()
# Out:
# Model: "MINI-XCEPTION"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# image (InputLayer)              [(None, 96, 96, 1)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 96, 96, 8)    72          image[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 96, 96, 8)    32          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 96, 96, 8)    0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 96, 96, 16)   1152        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 96, 96, 16)   64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 96, 96, 16)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# separable_conv2d (SeparableConv (None, 96, 96, 16)   400         activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 96, 96, 16)   64          separable_conv2d[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 96, 96, 16)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_1 (SeparableCo (None, 96, 96, 16)   400         activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 96, 96, 16)   64          separable_conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 48, 48, 16)   256         activation_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 48, 48, 16)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 48, 48, 16)   64          conv2d_2[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 48, 48, 16)   0           max_pooling2d[0][0]
#                                                                  batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_2 (SeparableCo (None, 48, 48, 32)   656         add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 48, 48, 32)   128         separable_conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 48, 48, 32)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_3 (SeparableCo (None, 48, 48, 32)   1312        activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 48, 48, 32)   128         separable_conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 24, 24, 32)   512         add[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 24, 24, 32)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 24, 24, 32)   128         conv2d_3[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 24, 24, 32)   0           max_pooling2d_1[0][0]
#                                                                  batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_4 (SeparableCo (None, 24, 24, 64)   2336        add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 24, 24, 64)   256         separable_conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 24, 24, 64)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_5 (SeparableCo (None, 24, 24, 64)   4672        activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 24, 24, 64)   256         separable_conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 12, 12, 64)   2048        add_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 12, 12, 64)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 12, 12, 64)   256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 12, 12, 64)   0           max_pooling2d_2[0][0]
#                                                                  batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_6 (SeparableCo (None, 12, 12, 128)  8768        add_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 12, 12, 128)  512         separable_conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 12, 12, 128)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_7 (SeparableCo (None, 12, 12, 128)  17536       activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 12, 12, 128)  512         separable_conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 6, 6, 128)    8192        add_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 6, 6, 128)    0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 6, 6, 128)    512         conv2d_5[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 6, 6, 128)    0           max_pooling2d_3[0][0]
#                                                                  batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 6, 6, 4)      4612        add_3[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 4)            0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# label (Activation)              (None, 4)            0           global_average_pooling2d[0][0]
# ==================================================================================================
# Total params: 55,900
# Trainable params: 54,412
# Non-trainable params: 1,488
# __________________________________________________________________________________________________

# %%
# check weights BEFORE loading pretrained model (second conv layer)
print(model.layers[1].get_weights()[0])
# Out:
# [[[[ 0.1487208   0.04504052  0.08439493 -0.1733607  -0.05161296
#     -0.12433307 -0.06567085  0.12211633]]
#
#   [[ 0.20209298  0.14931566 -0.27014968 -0.15539922 -0.17741272
#      0.20195833 -0.19076791  0.2373327 ]]
#
#   [[-0.04493974 -0.21775824  0.04011425  0.24174488 -0.23093116
#     -0.21730714  0.02564567  0.2607783 ]]]
#
#
#  [[[ 0.24340802  0.12731454  0.1084058   0.01785299 -0.2543125
#      0.2424931   0.05726632  0.20496836]]
#
#   [[-0.13325982  0.23459905  0.26989496  0.07654843  0.01016757
#     -0.03883523  0.01398644  0.02530792]]
#
#   [[ 0.1232101   0.04747784 -0.04573134  0.09715047  0.13595083
#      0.17142603  0.0062885  -0.08161967]]]
#
#
#  [[[ 0.0943749  -0.1368835  -0.17053913  0.18167803  0.00242522
#      0.06695643  0.06624961 -0.19963363]]
#
#   [[-0.01593143  0.15150845  0.19179219 -0.08778694  0.25803113
#     -0.22782576 -0.2620764   0.24952209]]
#
#   [[ 0.10843578  0.07209289  0.06292123 -0.10812981  0.2612118
#      0.11264864 -0.00313792 -0.06093465]]]]

# %%
# path to pretrained model checkpoint
pretrained_checkpoint_prefix = os.path.join("../../../pretraining/results/" + pretraining_mode + "/checkpoints/sonar1/" + model_name + "/batch_size_128/96x96_substract_mean_online_aug_width_16")

# optimizer
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001, beta_1=0.5, epsilon=1)

# define pretrained checkpoint model
checkpoint_pretrained = tf.train.Checkpoint(step=tf.Variable(1), optimizer=optimizer, model=model) # 4 ssl, 11 sl
manager_pretrained = tf.train.CheckpointManager(checkpoint_pretrained, pretrained_checkpoint_prefix, max_to_keep=3)

# restore model weights
checkpoint_pretrained.restore(manager_pretrained.latest_checkpoint)

if manager_pretrained.latest_checkpoint:
    print("[INFO] Pretrained checkpoint restored correctly: {}".format(manager_pretrained.latest_checkpoint))
else:
    print("[INFO] Could not restore pretrained checkpoint correctly, make sure path to pre-trained folder is correct.")
# Out:
# [INFO] Pretrained checkpoint restored correctly: ../../../pretraining/results/self_supervised_learning/checkpoints/sonar1/minixception/batch_size_128/96x96_substract_mean_online_aug_width_16/ckpt-21

# %%
# check weights AFTER loading pretrained model (second conv layer)
print(model.layers[1].get_weights()[0])
# Out:
# [[[[-0.01201695  0.10008978 -0.13219346  0.00733798 -0.07005484
#     -0.04808217  0.12624699 -0.18287827]]
#
#   [[ 0.13855451 -0.14625448 -0.21844625  0.17071846  0.09405775
#     -0.24085402  0.10183581 -0.14387022]]
#
#   [[-0.01798811 -0.02620124  0.00532504  0.24450086  0.05492317
#     -0.03963403 -0.09577609 -0.17052881]]]
#
#
#  [[[-0.19742756 -0.02938295  0.18144004 -0.07417174 -0.04067294
#     -0.11615404  0.3142947  -0.22881457]]
#
#   [[ 0.04655689 -0.25744978 -0.01958997 -0.2519868  -0.15674144
#     -0.01226818 -0.10892429  0.05615671]]
#
#   [[-0.1150781  -0.01644535  0.18481599  0.01680727  0.00066687
#      0.02181816 -0.06617652  0.00829394]]]
#
#
#  [[[-0.2902653   0.07897053 -0.22257775  0.06865413  0.2949624
#      0.03776029  0.08550944  0.02152358]]
#
#   [[ 0.04263758  0.26212874  0.15081672 -0.01832337  0.3247206
#      0.24757573 -0.24490963 -0.01840872]]
#
#   [[ 0.25585535 -0.04240311 -0.12157271 -0.16576783  0.03661726
#      0.16615067 -0.18297872 -0.2156377 ]]]]

# %% [markdown]
# ### Define models up to intermediate layers

# %%
print("Intermediate layers from model:", layers)
# Out:
# Intermediate layers from model: ['add_3', 'add_2', 'conv2d_6']

# %%
# https://stackoverflow.com/questions/63297838/how-can-i-obtain-the-output-of-an-intermediate-layer-feature-extraction
add_3 = tf.keras.Model(inputs=model.get_layer("image").output, 
                                     outputs=model.get_layer(layers[0]).output)

add_2 = tf.keras.Model(inputs=model.get_layer("image").output, 
                                     outputs=model.get_layer(layers[1]).output)

conv2d_6 = tf.keras.Model(inputs=model.get_layer("image").output, 
                                     outputs=model.get_layer(layers[2]).output)

# %% [markdown]
# ### Generate vector embeddings for train and test data (up to n-th layer)

# %%
# define tensorflow dataset
data_dir = "../../../../../../datasets/sonar_turntable_dataset_2/marine-debris-turntable-classification-object_classes-platform-96x96.hdf5"
train_dataset, test_dataset = load_sonar_turnedtable_supervised(data_dir)

# load tensorflow tensors individually
x_train, y_train = next(iter(train_dataset))
x_test, y_test = next(iter(test_dataset))
# Out:
# [INFO] Loading Tenorflow dataset
# [INFO] Retrieving Sonar Turned Table Supervised Data
# hdf5 dataset keys: <KeysViewHDF5 ['class_names', 'x_test', 'x_train', 'y_test', 'y_train']>
# [INFO] Data dimensions
# Train 1505
# Val 323
# Test 645
#
# [INFO] Tensorflow data dimensions
# <PrefetchDataset shapes: ((None, 96, 96, 1), (None,)), types: (tf.float32, tf.int64)>

# %%
# perform a forward pass to generate embeddings (both train and test data) (for each n-th layer)

# NOTE: when doing this all tensors are loaded into memory, this saturates NVIDIA memory (nvidia-smi)
x_train_add_3 = add_3([x_train], training=False)
x_train_add_2 = add_2([x_train], training=False)
x_train_conv2d_6 = conv2d_6([x_train], training=False)

x_test_add_3 = add_3([x_test], training=False)
x_test_add_2 = add_2([x_test], training=False)
x_test_conv2d_6 = conv2d_6([x_test], training=False)
# Out:
# ---------------------------------------------------------------------------
# _FallbackException                        Traceback (most recent call last)
# ~/anaconda3/envs/rotnet/lib/python3.6/site-packages/tensorflow/python/ops/gen_nn_ops.py in conv2d(input, filter, strides, padding, use_cudnn_on_gpu, explicit_paddings, data_format, dilations, name)
#     925         "explicit_paddings", explicit_paddings, "data_format", data_format,
# --> 926         "dilations", dilations)
#     927       return _result
#
# _FallbackException: Expecting int64_t value for attr strides, got numpy.int32
#
# During handling of the above exception, another exception occurred:
#
# InternalError                             Traceback (most recent call last)
# <ipython-input-16-fc395a4d30f7> in <module>
#       2
#       3 # NOTE: when doing this all tensors are loaded into memory, this saturates NVIDIA memory (nvidia-smi)
# ----> 4 x_train_add_3 = add_3([x_train], training=False)
#       5 x_train_add_2 = add_2([x_train], training=False)
#       6 x_train_conv2d_6 = conv2d_6([x_train], training=False)
#
# ~/anaconda3/envs/rotnet/lib/python3.6/site-packages/tensorflow/python/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#     966           with base_layer_utils.autocast_context_manager(
#     967               self._compute_dtype):
# --> 968             outputs = self.call(cast_inputs, *args, **kwargs)
#     969           self._handle_activity_regularization(inputs, outputs)
#     970           self._set_mask_metadata(inputs, outputs, input_masks)
#
# ~/anaconda3/envs/rotnet/lib/python3.6/site-packages/tensorflow/python/keras/engine/network.py in call(self, inputs, training, mask)
#     717     return self._run_internal_graph(
#     718         inputs, training=training, mask=mask,
# --> 719         convert_kwargs_to_constants=base_layer_utils.call_context().saving)
#     720
#     721   def compute_output_shape(self, input_shape):
#
# ~/anaconda3/envs/rotnet/lib/python3.6/site-packages/tensorflow/python/keras/engine/network.py in _run_internal_graph(self, inputs, training, mask, convert_kwargs_to_constants)
#     886
#     887           # Compute outputs.
# --> 888           output_tensors = layer(computed_tensors, **kwargs)
#     889
#     890           # Update tensor_dict.
#
# ~/anaconda3/envs/rotnet/lib/python3.6/site-packages/tensorflow/python/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#     966           with base_layer_utils.autocast_context_manager(
#     967               self._compute_dtype):
# --> 968             outputs = self.call(cast_inputs, *args, **kwargs)
#     969           self._handle_activity_regularization(inputs, outputs)
#     970           self._set_mask_metadata(inputs, outputs, input_masks)
#
# ~/anaconda3/envs/rotnet/lib/python3.6/site-packages/tensorflow/python/keras/layers/convolutional.py in call(self, inputs)
#     205       inputs = array_ops.pad(inputs, self._compute_causal_padding())
#     206
# --> 207     outputs = self._convolution_op(inputs, self.kernel)
#     208
#     209     if self.use_bias:
#
# ~/anaconda3/envs/rotnet/lib/python3.6/site-packages/tensorflow/python/ops/nn_ops.py in __call__(self, inp, filter)
#    1104           call_from_convolution=False)
#    1105     else:
# -> 1106       return self.conv_op(inp, filter)
#    1107
#    1108
#
# ~/anaconda3/envs/rotnet/lib/python3.6/site-packages/tensorflow/python/ops/nn_ops.py in __call__(self, inp, filter)
#     636
#     637   def __call__(self, inp, filter):  # pylint: disable=redefined-builtin
# --> 638     return self.call(inp, filter)
#     639
#     640
#
# ~/anaconda3/envs/rotnet/lib/python3.6/site-packages/tensorflow/python/ops/nn_ops.py in __call__(self, inp, filter)
#     235         padding=self.padding,
#     236         data_format=self.data_format,
# --> 237         name=self.name)
#     238
#     239
#
# ~/anaconda3/envs/rotnet/lib/python3.6/site-packages/tensorflow/python/ops/nn_ops.py in conv2d(input, filter, strides, padding, use_cudnn_on_gpu, data_format, dilations, name, filters)
#    2012                            data_format=data_format,
#    2013                            dilations=dilations,
# -> 2014                            name=name)
#    2015
#    2016
#
# ~/anaconda3/envs/rotnet/lib/python3.6/site-packages/tensorflow/python/ops/gen_nn_ops.py in conv2d(input, filter, strides, padding, use_cudnn_on_gpu, explicit_paddings, data_format, dilations, name)
#     931             input, filter, strides=strides, use_cudnn_on_gpu=use_cudnn_on_gpu,
#     932             padding=padding, explicit_paddings=explicit_paddings,
# --> 933             data_format=data_format, dilations=dilations, name=name, ctx=_ctx)
#     934       except _core._SymbolicException:
#     935         pass  # Add nodes to the TensorFlow graph.
#
# ~/anaconda3/envs/rotnet/lib/python3.6/site-packages/tensorflow/python/ops/gen_nn_ops.py in conv2d_eager_fallback(input, filter, strides, padding, use_cudnn_on_gpu, explicit_paddings, data_format, dilations, name, ctx)
#    1020   explicit_paddings, "data_format", data_format, "dilations", dilations)
#    1021   _result = _execute.execute(b"Conv2D", 1, inputs=_inputs_flat, attrs=_attrs,
# -> 1022                              ctx=ctx, name=name)
#    1023   if _execute.must_record_gradient():
#    1024     _execute.record_gradient(
#
# ~/anaconda3/envs/rotnet/lib/python3.6/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# InternalError: Failed copying input tensor from /job:localhost/replica:0/task:0/device:CPU:0 to /job:localhost/replica:0/task:0/device:GPU:0 in order to run Conv2D: Dst tensor is not initialized. [Op:Conv2D]

# %%
# x_train_add_3
# Out:
# <tf.Tensor: shape=(1505, 6, 6, 128), dtype=float32, numpy=
# array([[[[ 2.02667928e+00,  1.25419867e+00,  3.97476506e+00, ...,
#            3.90269685e+00,  1.02311695e+00,  1.33685827e-01],
#          [ 7.14852035e-01,  1.28386438e+00,  1.82952583e+00, ...,
#            4.01716709e+00,  3.57535839e+00, -1.15940833e+00],
#          [ 4.86602724e-01,  1.33568931e+00, -4.27551389e-01, ...,
#            1.64240623e+00,  5.02710342e+00, -1.94920182e+00],
#          [-2.32546401e+00,  2.91767931e+00,  4.25891966e-01, ...,
#            3.29664040e+00,  4.59511518e+00, -1.07874632e+00],
#          [ 1.58441830e-02,  3.65500879e+00, -3.90215278e+00, ...,
#            1.21211171e+00,  2.75078177e+00,  3.04705644e+00],
#          [ 2.10274363e+00, -6.35860920e-01, -2.43832469e-01, ...,
#            2.02246523e+00,  3.17994404e+00,  1.20501363e+00]],
#
#         [[-5.65949535e+00,  4.10151196e+00,  4.51660252e+00, ...,
#            1.78682351e+00,  4.06615782e+00,  2.90247965e+00],
#          [ 2.04414740e-01,  4.59194183e+00, -1.43340731e+00, ...,
#            6.07137251e+00,  1.90698600e+00,  9.92801905e-01],
#          [ 2.55568004e+00,  3.82737780e+00, -4.10604239e-01, ...,
#            9.75430369e-01,  2.98943663e+00,  1.48102975e+00],
#          [-4.48776156e-01,  3.17299271e+00,  4.75614166e+00, ...,
#            2.28171515e+00,  1.88367712e+00,  1.97602749e-01],
#          [ 1.10456181e+00,  3.34783316e+00, -9.05348241e-01, ...,
#            4.92625296e-01,  2.16623878e+00,  2.11704493e+00],
#          [ 4.06559408e-01, -5.95290780e-01, -2.59317660e+00, ...,
#            2.47984648e+00,  3.74215269e+00,  2.95590949e+00]],
#
#         [[-2.00020432e+00,  4.07012415e+00,  2.79535317e+00, ...,
#            9.44907784e-01, -1.68213367e+00, -8.20665121e-01],
#          [ 4.90093440e-01,  3.59642124e+00,  4.73272353e-02, ...,
#            2.91234565e+00, -6.65710926e-01,  3.55782658e-01],
#          [ 1.62377739e+00,  3.21824741e+00, -1.82998586e+00, ...,
#            2.21586370e+00,  3.40251780e+00,  8.51436555e-01],
#          [-1.46663105e+00,  5.51092196e+00, -1.31957459e+00, ...,
#           -1.52363944e+00,  5.75836277e+00,  6.44544005e-01],
#          [ 1.14904612e-01,  4.13306093e+00, -3.80196428e+00, ...,
#            1.37892336e-01,  2.60043097e+00,  1.19383585e+00],
#          [ 5.33473253e-01, -4.11678553e-02, -3.37115097e+00, ...,
#            1.22746676e-01, -6.84556961e-02,  2.01545691e+00],
#          [ 2.34022951e+00,  1.03513479e+00,  2.33255529e+00, ...,
#            3.04909301e+00, -2.32172966e-01,  1.66177773e+00],
#          [ 2.09820107e-01,  1.10779166e+00,  1.69651842e+00, ...,
#            1.50814748e+00,  5.22526562e-01,  7.49316275e-01],
#          [ 1.73693717e-01,  2.27820337e-01,  9.76347506e-01, ...,
#            4.88652885e-01,  7.36439943e-01,  2.67348957e+00]]]],
#       dtype=float32)>

# %% [markdown]
# ### Transfer Learning setup: classification with subsamples per object class (few shot learning)

# %%
# transfer learning params
# SAMPLES_PER_CLASS = [1, 5, 10, 20, 30, 40, 50] # NOTE: taking more samples per class since it is 88 for 50
# SAMPLES_PER_CLASS = [10, 20, 30, 40, 50, 70, 90, 110, 130, 150, len(x_test)]
SAMPLES_PER_CLASS = [10, 20, 30, 40, 50, 80, 110, 140, 170, 200]
TRIALS = 10

NUM_CLASSES_WATERTANK = 11
NUM_CLASSES_TURNEDTABLE = 12

# %%
# Flatten train & test data for SVM
x_train_add_3 = flatten(x_train_add_3.numpy())
x_train_add_2 = flatten(x_train_add_2.numpy())
x_train_conv2d_6 = flatten(x_train_conv2d_6.numpy())

x_test_add_3 = flatten(x_test_add_3.numpy())
x_test_add_2 = flatten(x_test_add_2.numpy())
x_test_conv2d_6 = flatten(x_test_conv2d_6.numpy())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-39689260da76> in <module>
#       1 # Flatten train & test data for SVM
# ----> 2 x_train_add_3 = flatten(x_train_add_3.numpy())
#       3 x_train_add_2 = flatten(x_train_add_2.numpy())
#       4 x_train_conv2d_6 = flatten(x_train_conv2d_6.numpy())
#       5
#
# NameError: name 'flatten' is not defined

# %%
# these two are not modified (only x_test, x_train)
print(y_train.numpy().shape)
print(y_test.numpy().shape)

y_train = y_train.numpy() # convert from tf tensor --> numpy
y_test = y_test.numpy()
# Out:
# (1505,)
# (645,)

# %% [markdown]
# ### Run svm tl evaluation with spc for each n-th layer

# %%
def train_svm_with_spc(x_train, y_train, x_test, y_test):
    """
    Takes embeddings from pretrained model and evaluates transfer learning 
    with few samples per class.
    """
    # NOTE: svm takes original labels (not one-hot encoding)
    for spc in SAMPLES_PER_CLASS:
        accuracies = []

        for i in range(TRIALS):
            x_sample, y_sample = classSampling(x_train, y_train, spc, NUM_CLASSES_TURNEDTABLE)

            svm = SVC(C=1.0, decision_function_shape = 'ovo', kernel="linear")
            svm.fit(x_sample, y_sample)

            train_acc = svm.score(x_sample, y_sample)
            test_acc = svm.score(x_test, y_test)

            print("SPC {} Train Accuracy: {:.3f}".format(spc, train_acc))
            print("SPC {} Test Accuracy: {:.3f}".format(spc, test_acc))
            print()

            accuracies.append(test_acc)

        mean_acc = np.mean(accuracies)
        std_acc = np.std(accuracies)

        mean_acc = round(100 * mean_acc, 3)
        std_acc = round(100 * std_acc, 3)

        print("After {} trials - Test Accuracy is {} +- {}".format(TRIALS, mean_acc, std_acc ))
        print("------------------------------------------------------------------------------")
        print()

# %%
train_svm_with_spc(x_train_add_3, y_train, x_test_add_3, y_test)
# Out:
# SPC 10 Train Accuracy: 1.000
# SPC 10 Test Accuracy: 0.650
#
# SPC 10 Train Accuracy: 1.000
# SPC 10 Test Accuracy: 0.693
#
# SPC 10 Train Accuracy: 1.000
# SPC 10 Test Accuracy: 0.712
#
# SPC 10 Train Accuracy: 1.000
# SPC 10 Test Accuracy: 0.718
#
# SPC 10 Train Accuracy: 1.000
# SPC 10 Test Accuracy: 0.707
#
# SPC 10 Train Accuracy: 1.000
# SPC 10 Test Accuracy: 0.691
#
# SPC 10 Train Accuracy: 1.000
# SPC 10 Test Accuracy: 0.664
#
# SPC 10 Train Accuracy: 1.000
# SPC 10 Test Accuracy: 0.690
#
# SPC 10 Train Accuracy: 1.000
# SPC 10 Test Accuracy: 0.670
#
# SPC 10 Train Accuracy: 1.000
# SPC 10 Test Accuracy: 0.670
#
# After 10 trials - Test Accuracy is 68.636 +- 2.135
# ------------------------------------------------------------------------------
#
# SPC 20 Train Accuracy: 1.000
# SPC 20 Test Accuracy: 0.783
#
# SPC 20 Train Accuracy: 1.000
# SPC 20 Test Accuracy: 0.792
#
# SPC 20 Train Accuracy: 1.000
# SPC 20 Test Accuracy: 0.771
#
# SPC 20 Train Accuracy: 1.000
# SPC 20 Test Accuracy: 0.764
#
# SPC 20 Train Accuracy: 1.000
# SPC 20 Test Accuracy: 0.769
#
# SPC 20 Train Accuracy: 1.000
# SPC 20 Test Accuracy: 0.778
#
# SPC 20 Train Accuracy: 1.000
# SPC 20 Test Accuracy: 0.788
#
# SPC 20 Train Accuracy: 1.000
# SPC 20 Test Accuracy: 0.744
#
# SPC 20 Train Accuracy: 1.000
# SPC 20 Test Accuracy: 0.766
#
# SPC 20 Train Accuracy: 1.000
# SPC 20 Test Accuracy: 0.780
#
# After 10 trials - Test Accuracy is 77.349 +- 1.316
# ------------------------------------------------------------------------------
#
# SPC 30 Train Accuracy: 1.000
# SPC 30 Test Accuracy: 0.798
#
# SPC 30 Train Accuracy: 1.000
# SPC 30 Test Accuracy: 0.797
#
# SPC 30 Train Accuracy: 1.000
# SPC 30 Test Accuracy: 0.853
#
# SPC 30 Train Accuracy: 1.000
# SPC 30 Test Accuracy: 0.792
#
# SPC 30 Train Accuracy: 1.000
# SPC 30 Test Accuracy: 0.809
#
# SPC 30 Train Accuracy: 1.000
# SPC 30 Test Accuracy: 0.805
#
# SPC 30 Train Accuracy: 1.000
# SPC 30 Test Accuracy: 0.828
#
# SPC 30 Train Accuracy: 1.000
# SPC 30 Test Accuracy: 0.816
#
# SPC 30 Train Accuracy: 1.000
# SPC 30 Test Accuracy: 0.808
#
# SPC 30 Train Accuracy: 1.000
# SPC 30 Test Accuracy: 0.817
#
# After 10 trials - Test Accuracy is 81.225 +- 1.682
# ------------------------------------------------------------------------------
#
# SPC 40 Train Accuracy: 1.000
# SPC 40 Test Accuracy: 0.808
#
# SPC 40 Train Accuracy: 1.000
# SPC 40 Test Accuracy: 0.850
#
# SPC 40 Train Accuracy: 1.000
# SPC 40 Test Accuracy: 0.826
#
# SPC 40 Train Accuracy: 1.000
# SPC 40 Test Accuracy: 0.828
#
# SPC 40 Train Accuracy: 1.000
# SPC 40 Test Accuracy: 0.843
#
# SPC 40 Train Accuracy: 1.000
# SPC 40 Test Accuracy: 0.816
#
# SPC 40 Train Accuracy: 1.000
# SPC 40 Test Accuracy: 0.839
#
# SPC 40 Train Accuracy: 1.000
# SPC 40 Test Accuracy: 0.847
#
# SPC 40 Train Accuracy: 1.000
# SPC 40 Test Accuracy: 0.811
#
# SPC 40 Train Accuracy: 1.000
# SPC 40 Test Accuracy: 0.828
#
# After 10 trials - Test Accuracy is 82.946 +- 1.416
# ------------------------------------------------------------------------------
#
# SPC 50 Train Accuracy: 1.000
# SPC 50 Test Accuracy: 0.847
#
# SPC 50 Train Accuracy: 1.000
# SPC 50 Test Accuracy: 0.870
#
# SPC 50 Train Accuracy: 1.000
# SPC 50 Test Accuracy: 0.837
#
# SPC 50 Train Accuracy: 1.000
# SPC 50 Test Accuracy: 0.860
#
# SPC 50 Train Accuracy: 1.000
# SPC 50 Test Accuracy: 0.848
#
# SPC 50 Train Accuracy: 1.000
# SPC 50 Test Accuracy: 0.865
#
# SPC 50 Train Accuracy: 1.000
# SPC 50 Test Accuracy: 0.865
#
# SPC 50 Train Accuracy: 1.000
# SPC 50 Test Accuracy: 0.837
#
# SPC 50 Train Accuracy: 1.000
# SPC 50 Test Accuracy: 0.868
#
# SPC 50 Train Accuracy: 1.000
# SPC 50 Test Accuracy: 0.837
#
# After 10 trials - Test Accuracy is 85.349 +- 1.294
# ------------------------------------------------------------------------------
#
# SPC 80 Train Accuracy: 1.000
# SPC 80 Test Accuracy: 0.890
#
# SPC 80 Train Accuracy: 1.000
# SPC 80 Test Accuracy: 0.884
#
# SPC 80 Train Accuracy: 1.000
# SPC 80 Test Accuracy: 0.876
#
# SPC 80 Train Accuracy: 1.000
# SPC 80 Test Accuracy: 0.881
#
# SPC 80 Train Accuracy: 1.000
# SPC 80 Test Accuracy: 0.893
#
# SPC 80 Train Accuracy: 1.000
# SPC 80 Test Accuracy: 0.868
#
# SPC 80 Train Accuracy: 1.000
# SPC 80 Test Accuracy: 0.876
#
# SPC 80 Train Accuracy: 1.000
# SPC 80 Test Accuracy: 0.884
#
# SPC 80 Train Accuracy: 1.000
# SPC 80 Test Accuracy: 0.874
#
# SPC 80 Train Accuracy: 1.000
# SPC 80 Test Accuracy: 0.898
#
# After 10 trials - Test Accuracy is 88.233 +- 0.87
# ------------------------------------------------------------------------------
#
# SPC 110 Train Accuracy: 1.000
# SPC 110 Test Accuracy: 0.915
#
# SPC 110 Train Accuracy: 1.000
# SPC 110 Test Accuracy: 0.905
#
# SPC 110 Train Accuracy: 1.000
# SPC 110 Test Accuracy: 0.902
#
# SPC 110 Train Accuracy: 1.000
# SPC 110 Test Accuracy: 0.898
#
# SPC 110 Train Accuracy: 1.000
# SPC 110 Test Accuracy: 0.902
#
# SPC 110 Train Accuracy: 1.000
# SPC 110 Test Accuracy: 0.895
#
# SPC 110 Train Accuracy: 1.000
# SPC 110 Test Accuracy: 0.909
#
# SPC 110 Train Accuracy: 1.000
# SPC 110 Test Accuracy: 0.887
#
# SPC 110 Train Accuracy: 1.000
# SPC 110 Test Accuracy: 0.898
#
# SPC 110 Train Accuracy: 1.000
# SPC 110 Test Accuracy: 0.902
#
# After 10 trials - Test Accuracy is 90.124 +- 0.731
# ------------------------------------------------------------------------------
#
# SPC 140 Train Accuracy: 1.000
# SPC 140 Test Accuracy: 0.919
#
# SPC 140 Train Accuracy: 1.000
# SPC 140 Test Accuracy: 0.919
#
# SPC 140 Train Accuracy: 1.000
# SPC 140 Test Accuracy: 0.913
#
# SPC 140 Train Accuracy: 1.000
# SPC 140 Test Accuracy: 0.921
#
# SPC 140 Train Accuracy: 1.000
# SPC 140 Test Accuracy: 0.918
#
# SPC 140 Train Accuracy: 1.000
# SPC 140 Test Accuracy: 0.929
#
# SPC 140 Train Accuracy: 1.000
# SPC 140 Test Accuracy: 0.910
#
# SPC 140 Train Accuracy: 1.000
# SPC 140 Test Accuracy: 0.926
#
# SPC 140 Train Accuracy: 1.000
# SPC 140 Test Accuracy: 0.924
#
# SPC 140 Train Accuracy: 1.000
# SPC 140 Test Accuracy: 0.927
#
# After 10 trials - Test Accuracy is 92.062 +- 0.567
# ------------------------------------------------------------------------------
#
# SPC 170 Train Accuracy: 1.000
# SPC 170 Test Accuracy: 0.926
#
# SPC 170 Train Accuracy: 1.000
# SPC 170 Test Accuracy: 0.907
#
# SPC 170 Train Accuracy: 1.000
# SPC 170 Test Accuracy: 0.930
#
# SPC 170 Train Accuracy: 1.000
# SPC 170 Test Accuracy: 0.913
#
# SPC 170 Train Accuracy: 1.000
# SPC 170 Test Accuracy: 0.916
#
# SPC 170 Train Accuracy: 1.000
# SPC 170 Test Accuracy: 0.924
#
# SPC 170 Train Accuracy: 1.000
# SPC 170 Test Accuracy: 0.913
#
# SPC 170 Train Accuracy: 1.000
# SPC 170 Test Accuracy: 0.916
#
# SPC 170 Train Accuracy: 1.000
# SPC 170 Test Accuracy: 0.909
#
# SPC 170 Train Accuracy: 1.000
# SPC 170 Test Accuracy: 0.909
#
# After 10 trials - Test Accuracy is 91.628 +- 0.753
# ------------------------------------------------------------------------------
#
# SPC 200 Train Accuracy: 1.000
# SPC 200 Test Accuracy: 0.922
#
# SPC 200 Train Accuracy: 1.000
# SPC 200 Test Accuracy: 0.910
#
# SPC 200 Train Accuracy: 1.000
# SPC 200 Test Accuracy: 0.921
#
# SPC 200 Train Accuracy: 1.000
# SPC 200 Test Accuracy: 0.936
#
# SPC 200 Train Accuracy: 1.000
# SPC 200 Test Accuracy: 0.921
#
# SPC 200 Train Accuracy: 1.000
# SPC 200 Test Accuracy: 0.922
#
# SPC 200 Train Accuracy: 1.000
# SPC 200 Test Accuracy: 0.924
#
# SPC 200 Train Accuracy: 1.000
# SPC 200 Test Accuracy: 0.927
#
# SPC 200 Train Accuracy: 1.000
# SPC 200 Test Accuracy: 0.915
#
# SPC 200 Train Accuracy: 1.000
# SPC 200 Test Accuracy: 0.930
#
# After 10 trials - Test Accuracy is 92.295 +- 0.704
# ------------------------------------------------------------------------------

# %%
train_svm_with_spc(x_train_add_2, y_train, x_test_add_2, y_test)
# Out:
# SPC 10 Train Accuracy: 1.000
# SPC 10 Test Accuracy: 0.668
#
# SPC 10 Train Accuracy: 1.000
# SPC 10 Test Accuracy: 0.656
#
# SPC 10 Train Accuracy: 1.000
# SPC 10 Test Accuracy: 0.673
#
# SPC 10 Train Accuracy: 1.000
# SPC 10 Test Accuracy: 0.674
#
# SPC 10 Train Accuracy: 1.000
# SPC 10 Test Accuracy: 0.668
#
# SPC 10 Train Accuracy: 1.000
# SPC 10 Test Accuracy: 0.657
#
# SPC 10 Train Accuracy: 1.000
# SPC 10 Test Accuracy: 0.616
#
# SPC 10 Train Accuracy: 1.000
# SPC 10 Test Accuracy: 0.662
#
# SPC 10 Train Accuracy: 1.000
# SPC 10 Test Accuracy: 0.687
#
# SPC 10 Train Accuracy: 1.000
# SPC 10 Test Accuracy: 0.710
#
# After 10 trials - Test Accuracy is 66.713 +- 2.288
# ------------------------------------------------------------------------------
#
# SPC 20 Train Accuracy: 1.000
# SPC 20 Test Accuracy: 0.800
#
# SPC 20 Train Accuracy: 1.000
# SPC 20 Test Accuracy: 0.771
#
# SPC 20 Train Accuracy: 1.000
# SPC 20 Test Accuracy: 0.816
#
# SPC 20 Train Accuracy: 1.000
# SPC 20 Test Accuracy: 0.783
#
# SPC 20 Train Accuracy: 1.000
# SPC 20 Test Accuracy: 0.778
#
# SPC 20 Train Accuracy: 1.000
# SPC 20 Test Accuracy: 0.795
#
# SPC 20 Train Accuracy: 1.000
# SPC 20 Test Accuracy: 0.792
#
# SPC 20 Train Accuracy: 1.000
# SPC 20 Test Accuracy: 0.772
#
# SPC 20 Train Accuracy: 1.000
# SPC 20 Test Accuracy: 0.800
#
# SPC 20 Train Accuracy: 1.000
# SPC 20 Test Accuracy: 0.736
#
# After 10 trials - Test Accuracy is 78.434 +- 2.078
# ------------------------------------------------------------------------------
#
# SPC 30 Train Accuracy: 1.000
# SPC 30 Test Accuracy: 0.845
#
# SPC 30 Train Accuracy: 1.000
# SPC 30 Test Accuracy: 0.831
#
# SPC 30 Train Accuracy: 1.000
# SPC 30 Test Accuracy: 0.854
#
# SPC 30 Train Accuracy: 1.000
# SPC 30 Test Accuracy: 0.820
#
# SPC 30 Train Accuracy: 1.000
# SPC 30 Test Accuracy: 0.856
#
# SPC 30 Train Accuracy: 1.000
# SPC 30 Test Accuracy: 0.816
#
# SPC 30 Train Accuracy: 1.000
# SPC 30 Test Accuracy: 0.820
#
# SPC 30 Train Accuracy: 1.000
# SPC 30 Test Accuracy: 0.817
#
# SPC 30 Train Accuracy: 1.000
# SPC 30 Test Accuracy: 0.819
#
# SPC 30 Train Accuracy: 1.000
# SPC 30 Test Accuracy: 0.848
#
# After 10 trials - Test Accuracy is 83.256 +- 1.563
# ------------------------------------------------------------------------------
#
# SPC 40 Train Accuracy: 1.000
# SPC 40 Test Accuracy: 0.842
#
# SPC 40 Train Accuracy: 1.000
# SPC 40 Test Accuracy: 0.867
#
# SPC 40 Train Accuracy: 1.000
# SPC 40 Test Accuracy: 0.873
#
# SPC 40 Train Accuracy: 1.000
# SPC 40 Test Accuracy: 0.854
#
# SPC 40 Train Accuracy: 1.000
# SPC 40 Test Accuracy: 0.845
#
# SPC 40 Train Accuracy: 1.000
# SPC 40 Test Accuracy: 0.876
#
# SPC 40 Train Accuracy: 1.000
# SPC 40 Test Accuracy: 0.845
#
# SPC 40 Train Accuracy: 1.000
# SPC 40 Test Accuracy: 0.856
#
# SPC 40 Train Accuracy: 1.000
# SPC 40 Test Accuracy: 0.850
#
# SPC 40 Train Accuracy: 1.000
# SPC 40 Test Accuracy: 0.871
#
# After 10 trials - Test Accuracy is 85.783 +- 1.219
# ------------------------------------------------------------------------------
#
# SPC 50 Train Accuracy: 1.000
# SPC 50 Test Accuracy: 0.874
#
# SPC 50 Train Accuracy: 1.000
# SPC 50 Test Accuracy: 0.885
#
# SPC 50 Train Accuracy: 1.000
# SPC 50 Test Accuracy: 0.890
#
# SPC 50 Train Accuracy: 1.000
# SPC 50 Test Accuracy: 0.853
#
# SPC 50 Train Accuracy: 1.000
# SPC 50 Test Accuracy: 0.879
#
# SPC 50 Train Accuracy: 1.000
# SPC 50 Test Accuracy: 0.853
#
# SPC 50 Train Accuracy: 1.000
# SPC 50 Test Accuracy: 0.862
#
# SPC 50 Train Accuracy: 1.000
# SPC 50 Test Accuracy: 0.854
#
# SPC 50 Train Accuracy: 1.000
# SPC 50 Test Accuracy: 0.864
#
# SPC 50 Train Accuracy: 1.000
# SPC 50 Test Accuracy: 0.878
#
# After 10 trials - Test Accuracy is 86.915 +- 1.316
# ------------------------------------------------------------------------------
#
# SPC 80 Train Accuracy: 1.000
# SPC 80 Test Accuracy: 0.924
#
# SPC 80 Train Accuracy: 1.000
# SPC 80 Test Accuracy: 0.907
#
# SPC 80 Train Accuracy: 1.000
# SPC 80 Test Accuracy: 0.887
#
# SPC 80 Train Accuracy: 1.000
# SPC 80 Test Accuracy: 0.912
#
# SPC 80 Train Accuracy: 1.000
# SPC 80 Test Accuracy: 0.902
#
# SPC 80 Train Accuracy: 1.000
# SPC 80 Test Accuracy: 0.902
#
# SPC 80 Train Accuracy: 1.000
# SPC 80 Test Accuracy: 0.913
#
# SPC 80 Train Accuracy: 1.000
# SPC 80 Test Accuracy: 0.887
#
# SPC 80 Train Accuracy: 1.000
# SPC 80 Test Accuracy: 0.902
#
# SPC 80 Train Accuracy: 1.000
# SPC 80 Test Accuracy: 0.888
#
# After 10 trials - Test Accuracy is 90.248 +- 1.171
# ------------------------------------------------------------------------------
#
# SPC 110 Train Accuracy: 1.000
# SPC 110 Test Accuracy: 0.935
#
# SPC 110 Train Accuracy: 1.000
# SPC 110 Test Accuracy: 0.919
#
# SPC 110 Train Accuracy: 1.000
# SPC 110 Test Accuracy: 0.935
#
# SPC 110 Train Accuracy: 1.000
# SPC 110 Test Accuracy: 0.918
#
# SPC 110 Train Accuracy: 1.000
# SPC 110 Test Accuracy: 0.935
#
# SPC 110 Train Accuracy: 1.000
# SPC 110 Test Accuracy: 0.927
#
# SPC 110 Train Accuracy: 1.000
# SPC 110 Test Accuracy: 0.949
#
# SPC 110 Train Accuracy: 1.000
# SPC 110 Test Accuracy: 0.926
#
# SPC 110 Train Accuracy: 1.000
# SPC 110 Test Accuracy: 0.926
#
# SPC 110 Train Accuracy: 1.000
# SPC 110 Test Accuracy: 0.912
#
# After 10 trials - Test Accuracy is 92.806 +- 1.017
# ------------------------------------------------------------------------------
#
# SPC 140 Train Accuracy: 1.000
# SPC 140 Test Accuracy: 0.946
#
# SPC 140 Train Accuracy: 1.000
# SPC 140 Test Accuracy: 0.933
#
# SPC 140 Train Accuracy: 1.000
# SPC 140 Test Accuracy: 0.919
#
# SPC 140 Train Accuracy: 1.000
# SPC 140 Test Accuracy: 0.936
#
# SPC 140 Train Accuracy: 1.000
# SPC 140 Test Accuracy: 0.936
#
# SPC 140 Train Accuracy: 1.000
# SPC 140 Test Accuracy: 0.932
#
# SPC 140 Train Accuracy: 1.000
# SPC 140 Test Accuracy: 0.929
#
# SPC 140 Train Accuracy: 1.000
# SPC 140 Test Accuracy: 0.943
#
# SPC 140 Train Accuracy: 1.000
# SPC 140 Test Accuracy: 0.941
#
# SPC 140 Train Accuracy: 1.000
# SPC 140 Test Accuracy: 0.938
#
# After 10 trials - Test Accuracy is 93.535 +- 0.721
# ------------------------------------------------------------------------------
#
# SPC 170 Train Accuracy: 1.000
# SPC 170 Test Accuracy: 0.947
#
# SPC 170 Train Accuracy: 1.000
# SPC 170 Test Accuracy: 0.941
#
# SPC 170 Train Accuracy: 1.000
# SPC 170 Test Accuracy: 0.944
#
# SPC 170 Train Accuracy: 1.000
# SPC 170 Test Accuracy: 0.950
#
# SPC 170 Train Accuracy: 1.000
# SPC 170 Test Accuracy: 0.946
#
# SPC 170 Train Accuracy: 1.000
# SPC 170 Test Accuracy: 0.929
#
# SPC 170 Train Accuracy: 1.000
# SPC 170 Test Accuracy: 0.958
#
# SPC 170 Train Accuracy: 1.000
# SPC 170 Test Accuracy: 0.952
#
# SPC 170 Train Accuracy: 1.000
# SPC 170 Test Accuracy: 0.944
#
# SPC 170 Train Accuracy: 1.000
# SPC 170 Test Accuracy: 0.936
#
# After 10 trials - Test Accuracy is 94.481 +- 0.782
# ------------------------------------------------------------------------------
#
# SPC 200 Train Accuracy: 1.000
# SPC 200 Test Accuracy: 0.957
#
# SPC 200 Train Accuracy: 1.000
# SPC 200 Test Accuracy: 0.943
#
# SPC 200 Train Accuracy: 1.000
# SPC 200 Test Accuracy: 0.955
#
# SPC 200 Train Accuracy: 1.000
# SPC 200 Test Accuracy: 0.952
#
# SPC 200 Train Accuracy: 1.000
# SPC 200 Test Accuracy: 0.957
#
# SPC 200 Train Accuracy: 1.000
# SPC 200 Test Accuracy: 0.955
#
# SPC 200 Train Accuracy: 1.000
# SPC 200 Test Accuracy: 0.952
#
# SPC 200 Train Accuracy: 1.000
# SPC 200 Test Accuracy: 0.961
#
# SPC 200 Train Accuracy: 1.000
# SPC 200 Test Accuracy: 0.946
#
# SPC 200 Train Accuracy: 1.000
# SPC 200 Test Accuracy: 0.953
#
# After 10 trials - Test Accuracy is 95.302 +- 0.514
# ------------------------------------------------------------------------------

# %%
train_svm_with_spc(x_train_conv2d_6, y_train, x_test_conv2d_6, y_test)
# Out:
# SPC 10 Train Accuracy: 1.000
# SPC 10 Test Accuracy: 0.532
#
# SPC 10 Train Accuracy: 1.000
# SPC 10 Test Accuracy: 0.476
#
# SPC 10 Train Accuracy: 1.000
# SPC 10 Test Accuracy: 0.532
#
# SPC 10 Train Accuracy: 1.000
# SPC 10 Test Accuracy: 0.509
#
# SPC 10 Train Accuracy: 1.000
# SPC 10 Test Accuracy: 0.575
#
# SPC 10 Train Accuracy: 1.000
# SPC 10 Test Accuracy: 0.530
#
# SPC 10 Train Accuracy: 1.000
# SPC 10 Test Accuracy: 0.549
#
# SPC 10 Train Accuracy: 1.000
# SPC 10 Test Accuracy: 0.526
#
# SPC 10 Train Accuracy: 1.000
# SPC 10 Test Accuracy: 0.530
#
# SPC 10 Train Accuracy: 1.000
# SPC 10 Test Accuracy: 0.516
#
# After 10 trials - Test Accuracy is 52.744 +- 2.434
# ------------------------------------------------------------------------------
#
# SPC 20 Train Accuracy: 1.000
# SPC 20 Test Accuracy: 0.598
#
# SPC 20 Train Accuracy: 1.000
# SPC 20 Test Accuracy: 0.639
#
# SPC 20 Train Accuracy: 1.000
# SPC 20 Test Accuracy: 0.623
#
# SPC 20 Train Accuracy: 1.000
# SPC 20 Test Accuracy: 0.558
#
# SPC 20 Train Accuracy: 1.000
# SPC 20 Test Accuracy: 0.606
#
# SPC 20 Train Accuracy: 1.000
# SPC 20 Test Accuracy: 0.602
#
# SPC 20 Train Accuracy: 1.000
# SPC 20 Test Accuracy: 0.555
#
# SPC 20 Train Accuracy: 1.000
# SPC 20 Test Accuracy: 0.566
#
# SPC 20 Train Accuracy: 1.000
# SPC 20 Test Accuracy: 0.580
#
# SPC 20 Train Accuracy: 1.000
# SPC 20 Test Accuracy: 0.625
#
# After 10 trials - Test Accuracy is 59.519 +- 2.795
# ------------------------------------------------------------------------------
#
# SPC 30 Train Accuracy: 1.000
# SPC 30 Test Accuracy: 0.631
#
# SPC 30 Train Accuracy: 1.000
# SPC 30 Test Accuracy: 0.634
#
# SPC 30 Train Accuracy: 1.000
# SPC 30 Test Accuracy: 0.620
#
# SPC 30 Train Accuracy: 1.000
# SPC 30 Test Accuracy: 0.625
#
# SPC 30 Train Accuracy: 1.000
# SPC 30 Test Accuracy: 0.656
#
# SPC 30 Train Accuracy: 1.000
# SPC 30 Test Accuracy: 0.589
#
# SPC 30 Train Accuracy: 1.000
# SPC 30 Test Accuracy: 0.609
#
# SPC 30 Train Accuracy: 1.000
# SPC 30 Test Accuracy: 0.645
#
# SPC 30 Train Accuracy: 1.000
# SPC 30 Test Accuracy: 0.639
#
# SPC 30 Train Accuracy: 1.000
# SPC 30 Test Accuracy: 0.625
#
# After 10 trials - Test Accuracy is 62.729 +- 1.777
# ------------------------------------------------------------------------------
#
# SPC 40 Train Accuracy: 1.000
# SPC 40 Test Accuracy: 0.650
#
# SPC 40 Train Accuracy: 1.000
# SPC 40 Test Accuracy: 0.682
#
# SPC 40 Train Accuracy: 1.000
# SPC 40 Test Accuracy: 0.648
#
# SPC 40 Train Accuracy: 1.000
# SPC 40 Test Accuracy: 0.650
#
# SPC 40 Train Accuracy: 1.000
# SPC 40 Test Accuracy: 0.647
#
# SPC 40 Train Accuracy: 1.000
# SPC 40 Test Accuracy: 0.668
#
# SPC 40 Train Accuracy: 1.000
# SPC 40 Test Accuracy: 0.662
#
# SPC 40 Train Accuracy: 1.000
# SPC 40 Test Accuracy: 0.682
#
# SPC 40 Train Accuracy: 1.000
# SPC 40 Test Accuracy: 0.636
#
# SPC 40 Train Accuracy: 1.000
# SPC 40 Test Accuracy: 0.651
#
# After 10 trials - Test Accuracy is 65.752 +- 1.485
# ------------------------------------------------------------------------------
#
# SPC 50 Train Accuracy: 1.000
# SPC 50 Test Accuracy: 0.684
#
# SPC 50 Train Accuracy: 1.000
# SPC 50 Test Accuracy: 0.682
#
# SPC 50 Train Accuracy: 1.000
# SPC 50 Test Accuracy: 0.681
#
# SPC 50 Train Accuracy: 1.000
# SPC 50 Test Accuracy: 0.698
#
# SPC 50 Train Accuracy: 1.000
# SPC 50 Test Accuracy: 0.673
#
# SPC 50 Train Accuracy: 1.000
# SPC 50 Test Accuracy: 0.687
#
# SPC 50 Train Accuracy: 1.000
# SPC 50 Test Accuracy: 0.676
#
# SPC 50 Train Accuracy: 1.000
# SPC 50 Test Accuracy: 0.665
#
# SPC 50 Train Accuracy: 1.000
# SPC 50 Test Accuracy: 0.699
#
# SPC 50 Train Accuracy: 1.000
# SPC 50 Test Accuracy: 0.664
#
# After 10 trials - Test Accuracy is 68.078 +- 1.14
# ------------------------------------------------------------------------------
#
# SPC 80 Train Accuracy: 1.000
# SPC 80 Test Accuracy: 0.702
#
# SPC 80 Train Accuracy: 1.000
# SPC 80 Test Accuracy: 0.676
#
# SPC 80 Train Accuracy: 1.000
# SPC 80 Test Accuracy: 0.710
#
# SPC 80 Train Accuracy: 1.000
# SPC 80 Test Accuracy: 0.704
#
# SPC 80 Train Accuracy: 1.000
# SPC 80 Test Accuracy: 0.682
#
# SPC 80 Train Accuracy: 1.000
# SPC 80 Test Accuracy: 0.704
#
# SPC 80 Train Accuracy: 1.000
# SPC 80 Test Accuracy: 0.691
#
# SPC 80 Train Accuracy: 1.000
# SPC 80 Test Accuracy: 0.695
#
# SPC 80 Train Accuracy: 1.000
# SPC 80 Test Accuracy: 0.695
#
# SPC 80 Train Accuracy: 1.000
# SPC 80 Test Accuracy: 0.707
#
# After 10 trials - Test Accuracy is 69.659 +- 1.047
# ------------------------------------------------------------------------------
#
# SPC 110 Train Accuracy: 1.000
# SPC 110 Test Accuracy: 0.690
#
# SPC 110 Train Accuracy: 1.000
# SPC 110 Test Accuracy: 0.709
#
# SPC 110 Train Accuracy: 1.000
# SPC 110 Test Accuracy: 0.710
#
# SPC 110 Train Accuracy: 1.000
# SPC 110 Test Accuracy: 0.713
#
# SPC 110 Train Accuracy: 1.000
# SPC 110 Test Accuracy: 0.716
#
# SPC 110 Train Accuracy: 1.000
# SPC 110 Test Accuracy: 0.705
#
# SPC 110 Train Accuracy: 1.000
# SPC 110 Test Accuracy: 0.709
#
# SPC 110 Train Accuracy: 1.000
# SPC 110 Test Accuracy: 0.704
#
# SPC 110 Train Accuracy: 1.000
# SPC 110 Test Accuracy: 0.704
#
# SPC 110 Train Accuracy: 1.000
# SPC 110 Test Accuracy: 0.732
#
# After 10 trials - Test Accuracy is 70.915 +- 1.01
# ------------------------------------------------------------------------------
#
# SPC 140 Train Accuracy: 1.000
# SPC 140 Test Accuracy: 0.696
#
# SPC 140 Train Accuracy: 1.000
# SPC 140 Test Accuracy: 0.702
#
# SPC 140 Train Accuracy: 1.000
# SPC 140 Test Accuracy: 0.716
#
# SPC 140 Train Accuracy: 1.000
# SPC 140 Test Accuracy: 0.705
#
# SPC 140 Train Accuracy: 1.000
# SPC 140 Test Accuracy: 0.727
#
# SPC 140 Train Accuracy: 1.000
# SPC 140 Test Accuracy: 0.713
#
# SPC 140 Train Accuracy: 1.000
# SPC 140 Test Accuracy: 0.705
#
# SPC 140 Train Accuracy: 1.000
# SPC 140 Test Accuracy: 0.710
#
# SPC 140 Train Accuracy: 1.000
# SPC 140 Test Accuracy: 0.716
#
# SPC 140 Train Accuracy: 1.000
# SPC 140 Test Accuracy: 0.705
#
# After 10 trials - Test Accuracy is 70.977 +- 0.834
# ------------------------------------------------------------------------------
#
# SPC 170 Train Accuracy: 1.000
# SPC 170 Test Accuracy: 0.727
#
# SPC 170 Train Accuracy: 1.000
# SPC 170 Test Accuracy: 0.713
#
# SPC 170 Train Accuracy: 1.000
# SPC 170 Test Accuracy: 0.740
#
# SPC 170 Train Accuracy: 1.000
# SPC 170 Test Accuracy: 0.729
#
# SPC 170 Train Accuracy: 1.000
# SPC 170 Test Accuracy: 0.726
#
# SPC 170 Train Accuracy: 1.000
# SPC 170 Test Accuracy: 0.730
#
# SPC 170 Train Accuracy: 1.000
# SPC 170 Test Accuracy: 0.727
#
# SPC 170 Train Accuracy: 1.000
# SPC 170 Test Accuracy: 0.716
#
# SPC 170 Train Accuracy: 1.000
# SPC 170 Test Accuracy: 0.726
#
# SPC 170 Train Accuracy: 1.000
# SPC 170 Test Accuracy: 0.727
#
# After 10 trials - Test Accuracy is 72.605 +- 0.687
# ------------------------------------------------------------------------------
#
# SPC 200 Train Accuracy: 1.000
# SPC 200 Test Accuracy: 0.752
#
# SPC 200 Train Accuracy: 1.000
# SPC 200 Test Accuracy: 0.743
#
# SPC 200 Train Accuracy: 1.000
# SPC 200 Test Accuracy: 0.729
#
# SPC 200 Train Accuracy: 1.000
# SPC 200 Test Accuracy: 0.747
#
# SPC 200 Train Accuracy: 1.000
# SPC 200 Test Accuracy: 0.726
#
# SPC 200 Train Accuracy: 1.000
# SPC 200 Test Accuracy: 0.729
#
# SPC 200 Train Accuracy: 1.000
# SPC 200 Test Accuracy: 0.724
#
# SPC 200 Train Accuracy: 1.000
# SPC 200 Test Accuracy: 0.740
#
# SPC 200 Train Accuracy: 1.000
# SPC 200 Test Accuracy: 0.738
#
# SPC 200 Train Accuracy: 1.000
# SPC 200 Test Accuracy: 0.747
#
# After 10 trials - Test Accuracy is 73.736 +- 0.954
# ------------------------------------------------------------------------------
