# %%
import h5py
import numpy as np
import sklearn
from sklearn.svm import SVC

# %%
# utilities
def flatten(x):
    return x.reshape((x.shape[0], -1))

def classSampling(X, y, samplesPerClass, numberOfClasses):
    X_ret = np.zeros((samplesPerClass * numberOfClasses, X.shape[1]), dtype = np.float32)
    y_ret = np.zeros((samplesPerClass * numberOfClasses), dtype = np.uint8)
    count = 0

    for classIdx in range(numberOfClasses):
        indices = np.where(y == classIdx)[0]

        #if len(indices) < samplesPerClass:
        #    raise IndexError("Not enough samples for class {} to produce {} samples per class. Only {} class samples available".format(classIdx, samplesPerClass, len(indices)))

        doResample = len(indices) < samplesPerClass

        chosenIndices = np.random.choice(indices, samplesPerClass, replace = doResample)

        for ci in chosenIndices:
            X_ret[count] = X[ci]
            y_ret[count] = y[ci]

            count += 1

    return X_ret, y_ret

# %%
# main params
NUM_CLASSES_WATERTANK = 11
NUM_CLASSES_TURNEDTABLE = 12

# SAMPLES_PER_CLASS = [1, 5, 10, 20, 30, 40, 50]
SAMPLES_PER_CLASS = [10, 20, 30, 40, 50, 80, 110, 140, 170, 200]

TRIALS = 10

# %% [markdown]
# ## SVM Classifier on Turnedtable Watertank (Dataset 2)

# %%
# Turnedtable Watertank Data

class SonarTurnedTableSupervised(object):
    def __init__(self, file_path):
        self.file_path = file_path

    def _normalize_images(self, images):
        """
        Normalize sonar images by 1/255.
        """
        return [element/255.0 for element in images]

    def get_sonar_data(self):
        """
        Reads from HDF5 file containing sonar data (resized to fix dims).
        Returns list of np arrays containing image data.
        """

        print("[INFO] Retrieving Sonar Turned Table Supervised Data")

        with h5py.File(self.file_path, "r") as f:
            # list all groups
            print("hdf5 dataset keys: %s" % f.keys())

            x_train = f["x_train"][...].astype(np.float32)
            y_train = f["y_train"][...]

            # x_val = list(f["x_val"])
            # y_val = list(f["y_val"])

            x_test = f["x_test"][...].astype(np.float32)
            y_test = f["y_test"][...]

            # x_train, x_val, y_train, y_val = train_test_split(x_train_val, y_train_val, train_size=0.83)

            print("[INFO] Data dimensions")
            print("Train", len(x_train))
            # print("Val", len(x_val))
            print("Test", len(x_test))
            # pdb.set_trace()

        # x_train = self._normalize_images(x_train)
        # x_val = self._normalize_images(x_val)
        # x_test = self._normalize_images(x_test)

        # return (x_train, y_train), (x_val, y_val), (x_test, y_test)
        
        return (x_train, y_train), (x_test, y_test)

# %%
ls ../../../../../../
# Out:
# datasets/  documentation/  literature/  models/  notes/  ros/

# %%
# Path to file
turnedtable_file_path = "../../../../../../datasets/sonar_turntable_dataset_2/marine-debris-turntable-classification-object_classes-platform-96x96.hdf5"

# Load data
turnedtable_dataset_object = SonarTurnedTableSupervised(turnedtable_file_path)
(x_train, y_train), (x_test, y_test) = turnedtable_dataset_object.get_sonar_data()
# Out:
# [INFO] Retrieving Sonar Turned Table Supervised Data
# hdf5 dataset keys: <KeysViewHDF5 ['class_names', 'x_test', 'x_train', 'y_test', 'y_train']>
# [INFO] Data dimensions
# Train 1505
# Test 645

# %%
x_train.shape
# Out:
# (1505, 96, 96, 1)

# %%
# Flatten train & test data for SVM
x_train = flatten(x_train)
x_test = flatten(x_test)

print(x_train.shape)
print(x_test.shape)
# Out:
# (1505, 9216)
# (645, 9216)

# %%
y_test
# Out:
# array([ 3,  9,  2,  1,  1,  0,  3,  0, 11,  0,  3,  1, 10,  0,  0,  0,  4,
#         0,  0,  9,  2,  0,  8,  0,  3,  2,  9,  2,  0,  1,  0,  9,  4,  0,
#        10,  0,  0,  9,  9,  1,  0,  0,  8,  1,  2,  2,  3,  0,  0,  0,  5,
#         0,  7, 10,  0,  0,  0, 11,  0, 11,  2, 10,  7,  2,  6,  0,  5,  0,
#         9, 11,  8,  8,  4,  8,  0,  6,  0,  5,  0,  0,  0,  0,  2,  2,  1,
#         0,  3,  0,  0,  9,  2,  1,  0,  7,  2,  0,  0,  0, 10,  2,  0,  6,
#         8,  0,  6,  3,  9,  0,  0, 10,  9,  7,  7, 11,  1,  5,  9, 11, 11,
#         1,  2,  0,  0,  0,  1,  8,  0,  0,  2,  5,  0,  0,  0, 10,  8,  9,
#         9,  0,  0,  9,  6,  4,  0,  7,  2,  9,  7,  8,  0,  5,  1,  9,  0,
#         9,  2,  5,  0,  2,  2,  0, 11,  4,  8,  9,  2,  6,  1,  0,  0, 10,
#         0,  0,  0,  0,  6,  0,  0,  0,  2, 10, 11,  0,  2,  0,  4,  2,  6,
#         9,  3,  9,  5,  5,  0,  0,  9,  9,  3,  3,  7,  4,  6,  8,  0,  0,
#         0, 11,  6,  2,  5,  0,  0,  9, 11,  2,  8,  6,  1,  0,  7,  5,  1,
#        11,  0,  0,  0,  3,  0,  3,  6,  0,  2,  0,  9,  9,  9,  0,  0,  6,
#         0,  9,  4,  4,  0, 11,  0,  0, 11,  9,  8,  5,  2,  9, 11,  0,  8,
#         0,  0, 10,  0,  3,  9,  0, 11,  0, 11,  0,  4,  3,  1,  1,  9,  0,
#         6,  0,  9,  0,  3,  0,  1,  5, 10,  9,  5,  5,  2,  5,  0,  0,  7,
#         7,  7,  9,  9,  0,  1,  7,  9,  2,  1,  6,  9,  5,  5,  2,  2, 10,
#         9,  0,  2,  0,  0,  9,  0,  2,  7,  7,  0, 10,  1,  9,  4,  9, 11,
#         2,  5,  1,  2,  1,  1,  6,  9,  8,  7,  1,  1,  7,  6,  2,  1,  0,
#         6,  4,  7,  2,  2,  2,  9, 11,  7,  3,  0,  1,  4,  0,  8,  0,  9,
#         6,  8,  5,  9,  2,  0,  9,  1,  2,  9,  1, 10,  8,  3,  0,  9,  0,
#         0,  0,  0,  1,  0,  2,  2,  4,  2,  0,  0,  9,  9,  0,  1,  0, 11,
#         1,  3,  7,  7, 11,  4,  2,  0,  6, 10, 11,  0,  0,  4,  0,  4,  3,
#         0,  4,  1,  2,  8,  8,  5,  6,  0,  2, 10, 10,  0,  0,  0,  7, 10,
#         3,  9,  0,  0,  0,  6,  0,  0,  0, 10,  0,  2,  9, 11, 10,  2, 11,
#         0,  0,  0,  6,  2,  6,  8,  0,  2,  0, 11,  0,  7,  1,  2,  1,  7,
#         0,  7,  0,  0, 11,  0,  9,  2,  9,  5, 10,  5,  0,  0,  1,  0,  1,
#         0,  5,  0, 11,  6,  0,  5,  0,  0,  6,  0,  4,  2, 11,  6,  9,  9,
#         0,  8,  1,  4,  0,  8,  2,  0,  0,  8, 10,  3,  0,  9,  2,  0,  8,
#         9,  0,  1,  0,  4,  1,  2,  9,  8,  0,  0,  8,  0,  0, 10,  8,  3,
#         0,  0,  4,  9,  0, 10,  1,  8,  9,  5,  0,  0,  7,  0,  7,  0,  0,
#         1,  4,  9,  0,  0,  0,  2,  2,  0,  0,  0,  0,  0,  0, 11,  0,  0,
#         8,  3,  1,  7,  8,  2,  1, 10,  3, 11,  7,  9,  9,  1,  1, 10,  7,
#        11,  7,  8,  6,  4, 10,  0, 10,  7,  1,  2,  0, 10, 10,  3,  6,  7,
#         6,  7,  7,  0,  1,  3,  1, 10,  3,  0,  0,  0,  8,  0,  1,  2,  3,
#         0,  2,  0,  0,  5,  0,  1,  0,  0,  1,  0,  0,  0, 10,  0,  1,  0,
#         0,  0,  0,  8,  0,  0,  6, 11,  0,  1,  6,  0, 11,  0,  9,  7])

# %% [markdown]
# ### Pretrainig setup: classification full turnedtable test set (your pipeline)

# %%
svm = SVC(C=1.0, decision_function_shape = 'ovo', kernel="linear")
# svm.fit(x_sample, y_sample)
svm.fit(x_train, y_train)

train_acc = svm.score(x_train, y_train)
test_acc = svm.score(x_test, y_test)

print("Full train set accuracy: {:.3f}".format(train_acc))
print("Full test set accuracy: {:.3f}".format(test_acc))
print()
# Out:
# Full train set accuracy: 1.000
# Full test set accuracy: 0.974

# %%
# value above is the same one as matias one!

# %% [markdown]
# ### Transfer Learning setup: classification with subsamples per class (your pipeline)

# %%
for spc in SAMPLES_PER_CLASS:
    accuracies = []
    
    for i in range(TRIALS):
        x_sample, y_sample = classSampling(x_train, y_train, spc, NUM_CLASSES_TURNEDTABLE)
        
        svm = SVC(C=1.0, decision_function_shape = 'ovo', kernel="linear")
        svm.fit(x_sample, y_sample)

        train_acc = svm.score(x_sample, y_sample)
        test_acc = svm.score(x_test, y_test)
        
        print("SPC {} Train Accuracy: {:.3f}".format(spc, train_acc))
        print("SPC {} Test Accuracy: {:.3f}".format(spc, test_acc))
        print()
        
        accuracies.append(test_acc)
    
    mean_acc = np.mean(accuracies)
    std_acc = np.std(accuracies)

    mean_acc = round(100 * mean_acc, 3)
    std_acc = round(100 * std_acc, 3)
    
    print("After {} trials - Test Accuracy is {} +- {}".format(TRIALS, mean_acc, std_acc ))
    print("------------------------------------------------------------------------------")
    print()
# Out:
# SPC 10 Train Accuracy: 1.000
# SPC 10 Test Accuracy: 0.608
#
# SPC 10 Train Accuracy: 1.000
# SPC 10 Test Accuracy: 0.659
#
# SPC 10 Train Accuracy: 1.000
# SPC 10 Test Accuracy: 0.709
#
# SPC 10 Train Accuracy: 1.000
# SPC 10 Test Accuracy: 0.603
#
# SPC 10 Train Accuracy: 1.000
# SPC 10 Test Accuracy: 0.580
#
# SPC 10 Train Accuracy: 1.000
# SPC 10 Test Accuracy: 0.678
#
# SPC 10 Train Accuracy: 1.000
# SPC 10 Test Accuracy: 0.622
#
# SPC 10 Train Accuracy: 1.000
# SPC 10 Test Accuracy: 0.651
#
# SPC 10 Train Accuracy: 1.000
# SPC 10 Test Accuracy: 0.616
#
# SPC 10 Train Accuracy: 1.000
# SPC 10 Test Accuracy: 0.631
#
# After 10 trials - Test Accuracy is 63.55 +- 3.663
# ------------------------------------------------------------------------------
#
# SPC 20 Train Accuracy: 1.000
# SPC 20 Test Accuracy: 0.729
#
# SPC 20 Train Accuracy: 1.000
# SPC 20 Test Accuracy: 0.767
#
# SPC 20 Train Accuracy: 1.000
# SPC 20 Test Accuracy: 0.771
#
# SPC 20 Train Accuracy: 1.000
# SPC 20 Test Accuracy: 0.743
#
# SPC 20 Train Accuracy: 1.000
# SPC 20 Test Accuracy: 0.792
#
# SPC 20 Train Accuracy: 1.000
# SPC 20 Test Accuracy: 0.791
#
# SPC 20 Train Accuracy: 1.000
# SPC 20 Test Accuracy: 0.792
#
# SPC 20 Train Accuracy: 1.000
# SPC 20 Test Accuracy: 0.761
#
# SPC 20 Train Accuracy: 1.000
# SPC 20 Test Accuracy: 0.746
#
# SPC 20 Train Accuracy: 1.000
# SPC 20 Test Accuracy: 0.761
#
# After 10 trials - Test Accuracy is 76.527 +- 2.098
# ------------------------------------------------------------------------------
#
# SPC 30 Train Accuracy: 1.000
# SPC 30 Test Accuracy: 0.822
#
# SPC 30 Train Accuracy: 1.000
# SPC 30 Test Accuracy: 0.816
#
# SPC 30 Train Accuracy: 1.000
# SPC 30 Test Accuracy: 0.809
#
# SPC 30 Train Accuracy: 1.000
# SPC 30 Test Accuracy: 0.826
#
# SPC 30 Train Accuracy: 1.000
# SPC 30 Test Accuracy: 0.789
#
# SPC 30 Train Accuracy: 1.000
# SPC 30 Test Accuracy: 0.817
#
# SPC 30 Train Accuracy: 1.000
# SPC 30 Test Accuracy: 0.828
#
# SPC 30 Train Accuracy: 1.000
# SPC 30 Test Accuracy: 0.836
#
# SPC 30 Train Accuracy: 1.000
# SPC 30 Test Accuracy: 0.831
#
# SPC 30 Train Accuracy: 1.000
# SPC 30 Test Accuracy: 0.809
#
# After 10 trials - Test Accuracy is 81.829 +- 1.286
# ------------------------------------------------------------------------------
#
# SPC 40 Train Accuracy: 1.000
# SPC 40 Test Accuracy: 0.860
#
# SPC 40 Train Accuracy: 1.000
# SPC 40 Test Accuracy: 0.857
#
# SPC 40 Train Accuracy: 1.000
# SPC 40 Test Accuracy: 0.857
#
# SPC 40 Train Accuracy: 1.000
# SPC 40 Test Accuracy: 0.836
#
# SPC 40 Train Accuracy: 1.000
# SPC 40 Test Accuracy: 0.865
#
# SPC 40 Train Accuracy: 1.000
# SPC 40 Test Accuracy: 0.860
#
# SPC 40 Train Accuracy: 1.000
# SPC 40 Test Accuracy: 0.856
#
# SPC 40 Train Accuracy: 1.000
# SPC 40 Test Accuracy: 0.845
#
# SPC 40 Train Accuracy: 1.000
# SPC 40 Test Accuracy: 0.836
#
# SPC 40 Train Accuracy: 1.000
# SPC 40 Test Accuracy: 0.867
#
# After 10 trials - Test Accuracy is 85.395 +- 1.071
# ------------------------------------------------------------------------------
#
# SPC 50 Train Accuracy: 1.000
# SPC 50 Test Accuracy: 0.876
#
# SPC 50 Train Accuracy: 1.000
# SPC 50 Test Accuracy: 0.884
#
# SPC 50 Train Accuracy: 1.000
# SPC 50 Test Accuracy: 0.885
#
# SPC 50 Train Accuracy: 1.000
# SPC 50 Test Accuracy: 0.867
#
# SPC 50 Train Accuracy: 1.000
# SPC 50 Test Accuracy: 0.859
#
# SPC 50 Train Accuracy: 1.000
# SPC 50 Test Accuracy: 0.893
#
# SPC 50 Train Accuracy: 1.000
# SPC 50 Test Accuracy: 0.891
#
# SPC 50 Train Accuracy: 1.000
# SPC 50 Test Accuracy: 0.854
#
# SPC 50 Train Accuracy: 1.000
# SPC 50 Test Accuracy: 0.884
#
# SPC 50 Train Accuracy: 1.000
# SPC 50 Test Accuracy: 0.887
#
# After 10 trials - Test Accuracy is 87.798 +- 1.29
# ------------------------------------------------------------------------------
#
# SPC 80 Train Accuracy: 1.000
# SPC 80 Test Accuracy: 0.893
#
# SPC 80 Train Accuracy: 1.000
# SPC 80 Test Accuracy: 0.929
#
# SPC 80 Train Accuracy: 1.000
# SPC 80 Test Accuracy: 0.904
#
# SPC 80 Train Accuracy: 1.000
# SPC 80 Test Accuracy: 0.924
#
# SPC 80 Train Accuracy: 1.000
# SPC 80 Test Accuracy: 0.881
#
# SPC 80 Train Accuracy: 1.000
# SPC 80 Test Accuracy: 0.898
#
# SPC 80 Train Accuracy: 1.000
# SPC 80 Test Accuracy: 0.913
#
# SPC 80 Train Accuracy: 1.000
# SPC 80 Test Accuracy: 0.910
#
# SPC 80 Train Accuracy: 1.000
# SPC 80 Test Accuracy: 0.909
#
# SPC 80 Train Accuracy: 1.000
# SPC 80 Test Accuracy: 0.873
#
# After 10 trials - Test Accuracy is 90.326 +- 1.68
# ------------------------------------------------------------------------------
#
# SPC 110 Train Accuracy: 1.000
# SPC 110 Test Accuracy: 0.927
#
# SPC 110 Train Accuracy: 1.000
# SPC 110 Test Accuracy: 0.927
#
# SPC 110 Train Accuracy: 1.000
# SPC 110 Test Accuracy: 0.922
#
# SPC 110 Train Accuracy: 1.000
# SPC 110 Test Accuracy: 0.927
#
# SPC 110 Train Accuracy: 1.000
# SPC 110 Test Accuracy: 0.913
#
# SPC 110 Train Accuracy: 1.000
# SPC 110 Test Accuracy: 0.916
#
# SPC 110 Train Accuracy: 1.000
# SPC 110 Test Accuracy: 0.918
#
# SPC 110 Train Accuracy: 1.000
# SPC 110 Test Accuracy: 0.924
#
# SPC 110 Train Accuracy: 1.000
# SPC 110 Test Accuracy: 0.938
#
# SPC 110 Train Accuracy: 1.000
# SPC 110 Test Accuracy: 0.938
#
# After 10 trials - Test Accuracy is 92.512 +- 0.791
# ------------------------------------------------------------------------------
#
# SPC 140 Train Accuracy: 1.000
# SPC 140 Test Accuracy: 0.941
#
# SPC 140 Train Accuracy: 1.000
# SPC 140 Test Accuracy: 0.950
#
# SPC 140 Train Accuracy: 1.000
# SPC 140 Test Accuracy: 0.933
#
# SPC 140 Train Accuracy: 1.000
# SPC 140 Test Accuracy: 0.944
#
# SPC 140 Train Accuracy: 1.000
# SPC 140 Test Accuracy: 0.943
#
# SPC 140 Train Accuracy: 1.000
# SPC 140 Test Accuracy: 0.940
#
# SPC 140 Train Accuracy: 1.000
# SPC 140 Test Accuracy: 0.950
#
# SPC 140 Train Accuracy: 1.000
# SPC 140 Test Accuracy: 0.933
#
# SPC 140 Train Accuracy: 1.000
# SPC 140 Test Accuracy: 0.936
#
# SPC 140 Train Accuracy: 1.000
# SPC 140 Test Accuracy: 0.926
#
# After 10 trials - Test Accuracy is 93.969 +- 0.742
# ------------------------------------------------------------------------------
#
# SPC 170 Train Accuracy: 1.000
# SPC 170 Test Accuracy: 0.947
#
# SPC 170 Train Accuracy: 1.000
# SPC 170 Test Accuracy: 0.940
#
# SPC 170 Train Accuracy: 1.000
# SPC 170 Test Accuracy: 0.964
#
# SPC 170 Train Accuracy: 1.000
# SPC 170 Test Accuracy: 0.949
#
# SPC 170 Train Accuracy: 1.000
# SPC 170 Test Accuracy: 0.953
#
# SPC 170 Train Accuracy: 1.000
# SPC 170 Test Accuracy: 0.941
#
# SPC 170 Train Accuracy: 1.000
# SPC 170 Test Accuracy: 0.947
#
# SPC 170 Train Accuracy: 1.000
# SPC 170 Test Accuracy: 0.947
#
# SPC 170 Train Accuracy: 1.000
# SPC 170 Test Accuracy: 0.947
#
# SPC 170 Train Accuracy: 1.000
# SPC 170 Test Accuracy: 0.952
#
# After 10 trials - Test Accuracy is 94.884 +- 0.654
# ------------------------------------------------------------------------------
#
# SPC 200 Train Accuracy: 1.000
# SPC 200 Test Accuracy: 0.957
#
# SPC 200 Train Accuracy: 1.000
# SPC 200 Test Accuracy: 0.961
#
# SPC 200 Train Accuracy: 1.000
# SPC 200 Test Accuracy: 0.947
#
# SPC 200 Train Accuracy: 1.000
# SPC 200 Test Accuracy: 0.944
#
# SPC 200 Train Accuracy: 1.000
# SPC 200 Test Accuracy: 0.944
#
# SPC 200 Train Accuracy: 1.000
# SPC 200 Test Accuracy: 0.953
#
# SPC 200 Train Accuracy: 1.000
# SPC 200 Test Accuracy: 0.963
#
# SPC 200 Train Accuracy: 1.000
# SPC 200 Test Accuracy: 0.961
#
# SPC 200 Train Accuracy: 1.000
# SPC 200 Test Accuracy: 0.974
#
# SPC 200 Train Accuracy: 1.000
# SPC 200 Test Accuracy: 0.963
#
# After 10 trials - Test Accuracy is 95.674 +- 0.903
# ------------------------------------------------------------------------------

# %%
# these are for my results

# %% [markdown]
# ## SVM Classifier on Marine Debris Watertank (Dataset 1)

# %%
# Watertank Data

class SonarDebrisSupervised(object):
    def __init__(self, file_path):
        self.file_path = file_path

    def _normalize_images(self, images):

        """
        """
        # NOTE: HDF5 images are already normalized
        return [element/255.0 for element in images]

    def get_sonar_data(self):

        """
        Reads from HDF5 file containing sonar data (resized to fix dims).
        Returns list of np arrays containing image data.
        """

        print("[INFO] Retrieving Sonar Debris Supervised Data")
        with h5py.File(self.file_path, "r") as f:
            # get images and labels
            x_train = f["x_train"][...].astype(np.float32)
            y_train = f["y_train"][...]

            x_val = list(f["x_val"])
            y_val = list(f["y_val"])

            x_test = f["x_test"][...].astype(np.float32)
            y_test = f["y_test"][...]

            print("[INFO] Data dimensions")
            print("Train", len(x_train))
            print("Val", len(x_val))
            print("Test", len(x_test))

        return (x_train, y_train), (x_val, y_val), (x_test, y_test)

# %%
# Path to file
watertank_file_path = "../../../../../datasets/sonar_debris_dataset_1/marine-debris-watertank-release/marine-debris-watertank-classification-96x96.hdf5"

# Load data
dataset_object = SonarDebrisSupervised(watertank_file_path)
(x_train, y_train), (x_val, y_val), (x_test, y_test) = dataset_object.get_sonar_data()
# Out:
# [INFO] Retrieving Sonar Debris Supervised Data
# [INFO] Data dimensions
# Train 1838
# Val 394
# Test 395

# %%
# Matias normalization
# x_train  *= 255.0
# x_test   *= 255.0

# x_train -= 84.51
# x_test  -= 84.51

# %%
x_train.shape
# Out:
# (1838, 96, 96, 1)

# %%
# Flatten train & test data for SVM
x_train = flatten(x_train)
x_test = flatten(x_test)

# %%
x_train.shape
# Out:
# (1838, 9216)

# %%
x_test.shape
# Out:
# (395, 9216)

# %% [markdown]
# ### Pretraining setup: classification full test set (your pipeline)

# %%
# Run full test set SVM classification (your pipeline)

# x_sample, y_sample = classSampling(x_train, y_train, spc, NUM_CLASSES)
svm = SVC(C=1.0, decision_function_shape = 'ovo', kernel="linear")
# svm.fit(x_sample, y_sample)
svm.fit(x_train, y_train)

train_acc = svm.score(x_train, y_train)
test_acc = svm.score(x_test, y_test)

print("Full train set accuracy: {:.3f}".format(train_acc))
print("Full test set accuracy: {:.3f}".format(test_acc))
print()
# Out:
# Full train set accuracy: 1.000
# Full test set accuracy: 0.967

# %% [markdown]
# ### Transfer Learning setup: classification with subsamples per class (matias pipeline)

# %%
for spc in SAMPLES_PER_CLASS:
    accuracies = []
    
    for i in range(TRIALS):
        x_sample, y_sample = classSampling(x_train, y_train, spc, NUM_CLASSES_WATERTANK)
        
        svm = SVC(C=1.0, decision_function_shape = 'ovo', kernel="linear")
        svm.fit(x_sample, y_sample)

        train_acc = svm.score(x_sample, y_sample)
        test_acc = svm.score(x_test, y_test)
        
        print("SPC {} Train Accuracy: {:.3f}".format(spc, train_acc))
        print("SPC {} Test Accuracy: {:.3f}".format(spc, test_acc))
        print()
        
        accuracies.append(test_acc)
    
    mean_acc = np.mean(accuracies)
    std_acc = np.std(accuracies)

    mean_acc = round(100 * mean_acc, 3)
    std_acc = round(100 * std_acc, 3)
    
    print("After {} trials - Test Accuracy is {} +- {}".format(TRIALS, mean_acc, std_acc ))
    print("------------------------------------------------------------------------------")
    print()
# Out:
# SPC 1 Train Accuracy: 1.000
# SPC 1 Test Accuracy: 0.539
#
# SPC 1 Train Accuracy: 1.000
# SPC 1 Test Accuracy: 0.385
#
# SPC 1 Train Accuracy: 1.000
# SPC 1 Test Accuracy: 0.365
#
# SPC 1 Train Accuracy: 1.000
# SPC 1 Test Accuracy: 0.430
#
# SPC 1 Train Accuracy: 1.000
# SPC 1 Test Accuracy: 0.408
#
# SPC 1 Train Accuracy: 1.000
# SPC 1 Test Accuracy: 0.367
#
# SPC 1 Train Accuracy: 1.000
# SPC 1 Test Accuracy: 0.415
#
# SPC 1 Train Accuracy: 1.000
# SPC 1 Test Accuracy: 0.562
#
# SPC 1 Train Accuracy: 1.000
# SPC 1 Test Accuracy: 0.478
#
# SPC 1 Train Accuracy: 1.000
# SPC 1 Test Accuracy: 0.395
#
# After 10 trials - Test Accuracy is 43.443 +- 6.615
# ------------------------------------------------------------------------------
#
# SPC 5 Train Accuracy: 1.000
# SPC 5 Test Accuracy: 0.739
#
# SPC 5 Train Accuracy: 1.000
# SPC 5 Test Accuracy: 0.732
#
# SPC 5 Train Accuracy: 1.000
# SPC 5 Test Accuracy: 0.772
#
# SPC 5 Train Accuracy: 1.000
# SPC 5 Test Accuracy: 0.813
#
# SPC 5 Train Accuracy: 1.000
# SPC 5 Test Accuracy: 0.722
#
# SPC 5 Train Accuracy: 1.000
# SPC 5 Test Accuracy: 0.722
#
# SPC 5 Train Accuracy: 1.000
# SPC 5 Test Accuracy: 0.772
#
# SPC 5 Train Accuracy: 1.000
# SPC 5 Test Accuracy: 0.785
#
# SPC 5 Train Accuracy: 1.000
# SPC 5 Test Accuracy: 0.754
#
# SPC 5 Train Accuracy: 1.000
# SPC 5 Test Accuracy: 0.749
#
# After 10 trials - Test Accuracy is 75.595 +- 2.804
# ------------------------------------------------------------------------------
#
# SPC 10 Train Accuracy: 1.000
# SPC 10 Test Accuracy: 0.787
#
# SPC 10 Train Accuracy: 1.000
# SPC 10 Test Accuracy: 0.820
#
# SPC 10 Train Accuracy: 1.000
# SPC 10 Test Accuracy: 0.841
#
# SPC 10 Train Accuracy: 1.000
# SPC 10 Test Accuracy: 0.808
#
# SPC 10 Train Accuracy: 1.000
# SPC 10 Test Accuracy: 0.782
#
# SPC 10 Train Accuracy: 1.000
# SPC 10 Test Accuracy: 0.823
#
# SPC 10 Train Accuracy: 1.000
# SPC 10 Test Accuracy: 0.795
#
# SPC 10 Train Accuracy: 1.000
# SPC 10 Test Accuracy: 0.820
#
# SPC 10 Train Accuracy: 1.000
# SPC 10 Test Accuracy: 0.792
#
# SPC 10 Train Accuracy: 1.000
# SPC 10 Test Accuracy: 0.808
#
# After 10 trials - Test Accuracy is 80.759 +- 1.754
# ------------------------------------------------------------------------------
#
# SPC 20 Train Accuracy: 1.000
# SPC 20 Test Accuracy: 0.853
#
# SPC 20 Train Accuracy: 1.000
# SPC 20 Test Accuracy: 0.866
#
# SPC 20 Train Accuracy: 1.000
# SPC 20 Test Accuracy: 0.899
#
# SPC 20 Train Accuracy: 1.000
# SPC 20 Test Accuracy: 0.863
#
# SPC 20 Train Accuracy: 1.000
# SPC 20 Test Accuracy: 0.914
#
# SPC 20 Train Accuracy: 1.000
# SPC 20 Test Accuracy: 0.889
#
# SPC 20 Train Accuracy: 1.000
# SPC 20 Test Accuracy: 0.830
#
# SPC 20 Train Accuracy: 1.000
# SPC 20 Test Accuracy: 0.891
#
# SPC 20 Train Accuracy: 1.000
# SPC 20 Test Accuracy: 0.889
#
# SPC 20 Train Accuracy: 1.000
# SPC 20 Test Accuracy: 0.901
#
# After 10 trials - Test Accuracy is 87.949 +- 2.426
# ------------------------------------------------------------------------------
#
# SPC 30 Train Accuracy: 1.000
# SPC 30 Test Accuracy: 0.909
#
# SPC 30 Train Accuracy: 1.000
# SPC 30 Test Accuracy: 0.922
#
# SPC 30 Train Accuracy: 1.000
# SPC 30 Test Accuracy: 0.904
#
# SPC 30 Train Accuracy: 1.000
# SPC 30 Test Accuracy: 0.909
#
# SPC 30 Train Accuracy: 1.000
# SPC 30 Test Accuracy: 0.899
#
# SPC 30 Train Accuracy: 1.000
# SPC 30 Test Accuracy: 0.899
#
# SPC 30 Train Accuracy: 1.000
# SPC 30 Test Accuracy: 0.916
#
# SPC 30 Train Accuracy: 1.000
# SPC 30 Test Accuracy: 0.891
#
# SPC 30 Train Accuracy: 1.000
# SPC 30 Test Accuracy: 0.916
#
# SPC 30 Train Accuracy: 1.000
# SPC 30 Test Accuracy: 0.914
#
# After 10 trials - Test Accuracy is 90.785 +- 0.914
# ------------------------------------------------------------------------------
#
# SPC 40 Train Accuracy: 1.000
# SPC 40 Test Accuracy: 0.914
#
# SPC 40 Train Accuracy: 1.000
# SPC 40 Test Accuracy: 0.914
#
# SPC 40 Train Accuracy: 1.000
# SPC 40 Test Accuracy: 0.939
#
# SPC 40 Train Accuracy: 1.000
# SPC 40 Test Accuracy: 0.922
#
# SPC 40 Train Accuracy: 1.000
# SPC 40 Test Accuracy: 0.919
#
# SPC 40 Train Accuracy: 1.000
# SPC 40 Test Accuracy: 0.911
#
# SPC 40 Train Accuracy: 1.000
# SPC 40 Test Accuracy: 0.919
#
# SPC 40 Train Accuracy: 1.000
# SPC 40 Test Accuracy: 0.932
#
# SPC 40 Train Accuracy: 1.000
# SPC 40 Test Accuracy: 0.916
#
# SPC 40 Train Accuracy: 1.000
# SPC 40 Test Accuracy: 0.939
#
# After 10 trials - Test Accuracy is 92.253 +- 0.988
# ------------------------------------------------------------------------------
#
# SPC 50 Train Accuracy: 1.000
# SPC 50 Test Accuracy: 0.924
#
# SPC 50 Train Accuracy: 1.000
# SPC 50 Test Accuracy: 0.957
#
# SPC 50 Train Accuracy: 1.000
# SPC 50 Test Accuracy: 0.916
#
# SPC 50 Train Accuracy: 1.000
# SPC 50 Test Accuracy: 0.924
#
# SPC 50 Train Accuracy: 1.000
# SPC 50 Test Accuracy: 0.932
#
# SPC 50 Train Accuracy: 1.000
# SPC 50 Test Accuracy: 0.922
#
# SPC 50 Train Accuracy: 1.000
# SPC 50 Test Accuracy: 0.937
#
# SPC 50 Train Accuracy: 1.000
# SPC 50 Test Accuracy: 0.939
#
# SPC 50 Train Accuracy: 1.000
# SPC 50 Test Accuracy: 0.932
#
# SPC 50 Train Accuracy: 1.000
# SPC 50 Test Accuracy: 0.942
#
# After 10 trials - Test Accuracy is 93.241 +- 1.127
# ------------------------------------------------------------------------------
